# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import warnings
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
from statsmodels.tools.sm_exceptions import ConvergenceWarning

# %% [markdown]
# # Suppress warnings

# %%
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %%
DATA_PATH = "./datasets/datasets/generated_sales_dataset.json"

# %% [markdown]
# # Load dataset

# %%
def load_data(path=DATA_PATH):
    print("Loading data from:", path)
    df = pd.read_json(path, orient="records")
    return df

# %% [markdown]
# # Prepare daily aggregated sales & price time series

# %%
def prepare_time_series(df, product_code=None):
    if product_code:
        df = df[df['product_code'] == product_code]
    df['buying_date'] = pd.to_datetime(df['buying_date'])
    
    daily_sales = df.groupby('buying_date')['quantity'].sum().sort_index()
    daily_price = df.groupby('buying_date')['unit_price'].mean().sort_index()

    # Ensure daily frequency
    daily_sales = daily_sales.asfreq('D')
    daily_price = daily_price.asfreq('D')

    # Fill NaNs robustly
    daily_sales = daily_sales.fillna(0)
    daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')

    # Drop any residual NaNs
    daily_sales = daily_sales.dropna()
    daily_price = daily_price.dropna()

    return daily_sales, daily_price

# %% [markdown]
# # SARIMA forecasting

# %%
def sarima_forecast(series, order=(1,1,1), seasonal_order=(1,1,1,7), forecast_days=7):
    series = series.fillna(method='ffill').fillna(0)

    try:
        model = SARIMAX(series, order=order, seasonal_order=seasonal_order,
                        enforce_stationarity=False, enforce_invertibility=False)
        model_fit = model.fit(disp=False, maxiter=200, method='powell')
    except Exception as e:
        print(f"SARIMA failed with {order}, {seasonal_order}: {e}. Retrying with simpler model...")
        model = SARIMAX(series, order=(1,1,1), enforce_stationarity=False, enforce_invertibility=False)
        model_fit = model.fit(disp=False, maxiter=200, method='powell')

    forecast = model_fit.forecast(steps=forecast_days)

    today = pd.Timestamp.today().normalize()
    forecast_index = pd.date_range(start=today + pd.Timedelta(days=1),
                                   periods=forecast_days, freq='D')
    forecast.index = forecast_index

    return forecast, model_fit

# %% [markdown]
# # RMSE calculation

# %%
def calculate_rmse(true_values, predicted_values):
    df = pd.DataFrame({'true': true_values, 'pred': predicted_values}).dropna()
    if df.empty:
        return np.nan
    return np.sqrt(mean_squared_error(df['true'], df['pred']))

# %% [markdown]
# # Forecast for a single product

# %%
def forecast_for_product(df, product_code, forecast_days=7):
    sales_series, price_series = prepare_time_series(df, product_code)
    forecast_sales, model_fit_sales = sarima_forecast(sales_series, forecast_days=forecast_days)
    forecast_price, model_fit_price = sarima_forecast(price_series, forecast_days=forecast_days)

    rmse_sales = calculate_rmse(sales_series[-forecast_days:], forecast_sales) if len(sales_series) >= forecast_days else None
    rmse_price = calculate_rmse(price_series[-forecast_days:], forecast_price) if len(price_series) >= forecast_days else None

    predictions = {}
    for date, sale, price in zip(forecast_sales.index, forecast_sales.values, forecast_price.values):
        predictions[str(date.date())] = {
            "expected_sale_stock": round(float(sale), 2),
            "expected_price": round(float(price), 2)
        }

    return predictions, sales_series, forecast_sales, rmse_sales, price_series, forecast_price, rmse_price

# %% [markdown]
# # Forecast for all product codes

# %%
def forecast_for_all_products(df, forecast_days=7):
    all_products = df['product_code'].unique()
    results = {}
    for product_code in all_products:
        predictions, sales_series, forecast_sales, rmse_sales, price_series, forecast_price, rmse_price = forecast_for_product(df, product_code, forecast_days)
        for date, metrics in predictions.items():
            if date not in results:
                results[date] = {}
            results[date][product_code] = metrics
    return results

# %%
def main():
    df = load_data()

    print("Choose an option:\n1. Prediction for a specific product_code\n2. Prediction for next 7 days for all product codes")
    choice = input("Enter choice (1 or 2): ").strip()

    if choice == '1':
        product_code = input("Enter product_code to predict: ").strip()
        predictions, sales_series, forecast_sales, rmse_sales, price_series, forecast_price, rmse_price = forecast_for_product(df, product_code)

        print(f"\n7-day forecast for product_code: {product_code}")
        print(json.dumps(predictions, indent=4))
        if rmse_sales is not None and rmse_price is not None:
            print(f"RMSE Sales: {rmse_sales:.3f}, RMSE Price: {rmse_price:.3f}")

        # Plot sales
        plt.figure(figsize=(12,5))
        plt.plot(sales_series.index, sales_series.values, label='Historical Sales')
        plt.plot(forecast_sales.index, forecast_sales.values, label='Forecasted Sales', color='red')
        plt.title(f'Sales Forecast for {product_code}')
        plt.xlabel('Date')
        plt.ylabel('Quantity')
        plt.legend()
        plt.show()

        # Plot prices
        plt.figure(figsize=(12,5))
        plt.plot(price_series.index, price_series.values, label='Historical Price')
        plt.plot(forecast_price.index, forecast_price.values, label='Forecasted Price', color='green')
        plt.title(f'Price Forecast for {product_code}')
        plt.xlabel('Date')
        plt.ylabel('Unit Price')
        plt.legend()
        plt.show()

    elif choice == '2':
        results = forecast_for_all_products(df)
        print("\n7-day forecast for all product codes:")
        print(json.dumps(results, indent=4))
    else:
        print("Invalid choice. Exiting.")

# %%
if __name__ == '__main__':
    main()
# Out:
# Loading data from: ./datasets/datasets/generated_sales_dataset.json
# Choose an option:
# 1. Prediction for a specific product_code
# 2. Prediction for next 7 days for all product codes
# Enter choice (1 or 2):  2
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/4208608311.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buying_date'] = pd.to_datetime(df['buying_date'])
# /tmp/ipykernel_258/4208608311.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_price = daily_price.fillna(method='ffill').fillna(method='bfill')
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# /tmp/ipykernel_258/1607094272.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series = series.fillna(method='ffill').fillna(0)
# 7-day forecast for all product codes:
# {
#     "2025-10-13": {
#         "S1002": {
#             "expected_sale_stock": 1.35,
#             "expected_price": 2000.0
#         },
#         "S1004": {
#             "expected_sale_stock": 0.49,
#             "expected_price": 2500.0
#         },
#         "R1002": {
#             "expected_sale_stock": 0.98,
#             "expected_price": 2200.0
#         },
#         "F1003": {
#             "expected_sale_stock": 1.3,
#             "expected_price": 5500.0
#         },
#         "F1001": {
#             "expected_sale_stock": 1.46,
#             "expected_price": 1300.0
#         },
#         "F1002": {
#             "expected_sale_stock": 2.22,
#             "expected_price": 2500.0
#         },
#         "M1204": {
#             "expected_sale_stock": 0.05,
#             "expected_price": 1900.0
#         },
#         "S1005": {
#             "expected_sale_stock": 0.82,
#             "expected_price": 700.0
#         },
#         "S1006": {
#             "expected_sale_stock": 0.16,
#             "expected_price": 3000.0
#         },
#         "R1003": {
#             "expected_sale_stock": 0.83,
#             "expected_price": NaN
#         },
#         "S1001": {
#             "expected_sale_stock": 1.66,
#             "expected_price": 6000.0
#         },
#         "M1001": {
#             "expected_sale_stock": 26.68,
#             "expected_price": 1500.0
#         },
#         "M1101": {
#             "expected_sale_stock": 25.08,
#             "expected_price": 1500.0
#         },
#         "S1003": {
#             "expected_sale_stock": 0.61,
#             "expected_price": 900.0
#         },
#         "R1001": {
#             "expected_sale_stock": 1.21,
#             "expected_price": 1800.0
#         },
#         "M1401": {
#             "expected_sale_stock": 43.0,
#             "expected_price": 6000.0
#         },
#         "M1203": {
#             "expected_sale_stock": 0.2,
#             "expected_price": 2100.0
#         },
#         "M1201": {
#             "expected_sale_stock": 0.63,
#             "expected_price": 2000.0
#         },
#         "M1205": {
#             "expected_sale_stock": 0.98,
#             "expected_price": 2500.0
#         },
#         "M1202": {
#             "expected_sale_stock": 0.03,
#             "expected_price": 2200.0
#         },
#         "M1301": {
#             "expected_sale_stock": 46.72,
#             "expected_price": 2800.0
#         }
#     },
#     "2025-10-14": {
#         "S1002": {
#             "expected_sale_stock": 4.42,
#             "expected_price": 2000.0
#         },
#         "S1004": {
#             "expected_sale_stock": 0.64,
#             "expected_price": 2500.0
#         },
#         "R1002": {
#             "expected_sale_stock": 1.07,
#             "expected_price": 2200.0
#         },
#         "F1003": {
#             "expected_sale_stock": 1.45,
#             "expected_price": 5500.0
#         },
#         "F1001": {
#             "expected_sale_stock": 1.69,
#             "expected_price": 1300.0
#         },
#         "F1002": {
#             "expected_sale_stock": 1.95,
#             "expected_price": 2500.0
#         },
#         "M1204": {
#             "expected_sale_stock": 0.01,
#             "expected_price": 1900.0
#         },
#         "S1005": {
#             "expected_sale_stock": 0.58,
#             "expected_price": 700.0
#         },
#         "S1006": {
#             "expected_sale_stock": -0.03,
#             "expected_price": 3000.0
#         },
#         "R1003": {
#             "expected_sale_stock": 0.81,
#             "expected_price": NaN
#         },
#         "S1001": {
#             "expected_sale_stock": 0.84,
#             "expected_price": 6000.0
#         },
#         "M1001": {
#             "expected_sale_stock": 19.17,
#             "expected_price": 1500.0
#         },
#         "M1101": {
#             "expected_sale_stock": 17.35,
#             "expected_price": 1500.0
#         },
#         "S1003": {
#             "expected_sale_stock": 0.62,
#             "expected_price": 900.0
#         },
#         "R1001": {
#             "expected_sale_stock": 0.78,
#             "expected_price": 1800.0
#         },
#         "M1401": {
#             "expected_sale_stock": 43.0,
#             "expected_price": 6000.0
#         },
#         "M1203": {
#             "expected_sale_stock": -0.03,
#             "expected_price": 2100.0
#         },
#         "M1201": {
#             "expected_sale_stock": 0.26,
#             "expected_price": 2000.0
#         },
#         "M1205": {
#             "expected_sale_stock": 0.64,
#             "expected_price": 2500.0
#         },
#         "M1202": {
#             "expected_sale_stock": 0.01,
#             "expected_price": 2200.0
#         },
#         "M1301": {
#             "expected_sale_stock": 131.07,
#             "expected_price": 2800.0
#         }
#     },
#     "2025-10-15": {
#         "S1002": {
#             "expected_sale_stock": 0.48,
#             "expected_price": 2000.0
#         },
#         "S1004": {
#             "expected_sale_stock": 0.74,
#             "expected_price": 2500.0
#         },
#         "R1002": {
#             "expected_sale_stock": 1.13,
#             "expected_price": 2200.0
#         },
#         "F1003": {
#             "expected_sale_stock": 0.91,
#             "expected_price": 5500.0
#         },
#         "F1001": {
#             "expected_sale_stock": 1.14,
#             "expected_price": 1300.0
#         },
#         "F1002": {
#             "expected_sale_stock": 2.52,
#             "expected_price": 2500.0
#         },
#         "M1204": {
#             "expected_sale_stock": 0.11,
#             "expected_price": 1900.0
#         },
#         "S1005": {
#             "expected_sale_stock": 0.59,
#             "expected_price": 700.0
#         },
#         "S1006": {
#             "expected_sale_stock": -0.13,
#             "expected_price": 3000.0
#         },
#         "R1003": {
#             "expected_sale_stock": 0.97,
#             "expected_price": NaN
#         },
#         "S1001": {
#             "expected_sale_stock": 0.53,
#             "expected_price": 6000.0
#         },
#         "M1001": {
#             "expected_sale_stock": 14.4,
#             "expected_price": 1500.0
#         },
#         "M1101": {
#             "expected_sale_stock": 14.31,
#             "expected_price": 1500.0
#         },
#         "S1003": {
#             "expected_sale_stock": 0.74,
#             "expected_price": 900.0
#         },
#         "R1001": {
#             "expected_sale_stock": 1.0,
#             "expected_price": 1800.0
#         },
#         "M1401": {
#             "expected_sale_stock": 43.0,
#             "expected_price": 6000.0
#         },
#         "M1203": {
#             "expected_sale_stock": -0.02,
#             "expected_price": 2100.0
#         },
#         "M1201": {
#             "expected_sale_stock": 0.21,
#             "expected_price": 2000.0
#         },
#         "M1205": {
#             "expected_sale_stock": 0.58,
#             "expected_price": 2500.0
#         },
#         "M1202": {
#             "expected_sale_stock": 0.04,
#             "expected_price": 2200.0
#         },
#         "M1301": {
#             "expected_sale_stock": 342.05,
#             "expected_price": 2800.0
#         }
#     },
#     "2025-10-16": {
#         "S1002": {
#             "expected_sale_stock": 1.09,
#             "expected_price": 2000.0
#         },
#         "S1004": {
#             "expected_sale_stock": 0.83,
#             "expected_price": 2500.0
#         },
#         "R1002": {
#             "expected_sale_stock": 0.84,
#             "expected_price": 2200.0
#         },
#         "F1003": {
#             "expected_sale_stock": 1.2,
#             "expected_price": 5500.0
#         },
#         "F1001": {
#             "expected_sale_stock": 1.53,
#             "expected_price": 1300.0
#         },
#         "F1002": {
#             "expected_sale_stock": 1.77,
#             "expected_price": 2500.0
#         },
#         "M1204": {
#             "expected_sale_stock": 0.04,
#             "expected_price": 1900.0
#         },
#         "S1005": {
#             "expected_sale_stock": 0.61,
#             "expected_price": 700.0
#         },
#         "S1006": {
#             "expected_sale_stock": 0.82,
#             "expected_price": 3000.0
#         },
#         "R1003": {
#             "expected_sale_stock": 0.87,
#             "expected_price": NaN
#         },
#         "S1001": {
#             "expected_sale_stock": 0.74,
#             "expected_price": 6000.0
#         },
#         "M1001": {
#             "expected_sale_stock": 11.03,
#             "expected_price": 1500.0
#         },
#         "M1101": {
#             "expected_sale_stock": 13.06,
#             "expected_price": 1500.0
#         },
#         "S1003": {
#             "expected_sale_stock": 1.47,
#             "expected_price": 900.0
#         },
#         "R1001": {
#             "expected_sale_stock": 0.91,
#             "expected_price": 1800.0
#         },
#         "M1401": {
#             "expected_sale_stock": 43.0,
#             "expected_price": 6000.0
#         },
#         "M1203": {
#             "expected_sale_stock": 0.01,
#             "expected_price": 2100.0
#         },
#         "M1201": {
#             "expected_sale_stock": 0.19,
#             "expected_price": 2000.0
#         },
#         "M1205": {
#             "expected_sale_stock": 0.62,
#             "expected_price": 2500.0
#         },
#         "M1202": {
#             "expected_sale_stock": 0.07,
#             "expected_price": 2200.0
#         },
#         "M1301": {
#             "expected_sale_stock": 869.76,
#             "expected_price": 2800.0
#         }
#     },
#     "2025-10-17": {
#         "S1002": {
#             "expected_sale_stock": 0.43,
#             "expected_price": 2000.0
#         },
#         "S1004": {
#             "expected_sale_stock": 0.57,
#             "expected_price": 2500.0
#         },
#         "R1002": {
#             "expected_sale_stock": 0.65,
#             "expected_price": 2200.0
#         },
#         "F1003": {
#             "expected_sale_stock": 0.8,
#             "expected_price": 5500.0
#         },
#         "F1001": {
#             "expected_sale_stock": 1.62,
#             "expected_price": 1300.0
#         },
#         "F1002": {
#             "expected_sale_stock": 1.57,
#             "expected_price": 2500.0
#         },
#         "M1204": {
#             "expected_sale_stock": -0.02,
#             "expected_price": 1900.0
#         },
#         "S1005": {
#             "expected_sale_stock": 0.44,
#             "expected_price": 700.0
#         },
#         "S1006": {
#             "expected_sale_stock": 1.85,
#             "expected_price": 3000.0
#         },
#         "R1003": {
#             "expected_sale_stock": 0.91,
#             "expected_price": NaN
#         },
#         "S1001": {
#             "expected_sale_stock": 1.14,
#             "expected_price": 6000.0
#         },
#         "M1001": {
#             "expected_sale_stock": 9.97,
#             "expected_price": 1500.0
#         },
#         "M1101": {
#             "expected_sale_stock": 13.04,
#             "expected_price": 1500.0
#         },
#         "S1003": {
#             "expected_sale_stock": 0.98,
#             "expected_price": 900.0
#         },
#         "R1001": {
#             "expected_sale_stock": 0.77,
#             "expected_price": 1800.0
#         },
#         "M1401": {
#             "expected_sale_stock": 58.33,
#             "expected_price": 10000.0
#         },
#         "M1203": {
#             "expected_sale_stock": 0.05,
#             "expected_price": 2100.0
#         },
#         "M1201": {
#             "expected_sale_stock": 0.27,
#             "expected_price": 2000.0
#         },
#         "M1205": {
#             "expected_sale_stock": 0.8,
#             "expected_price": 2500.0
#         },
#         "M1202": {
#             "expected_sale_stock": 0.16,
#             "expected_price": 2200.0
#         },
#         "M1301": {
#             "expected_sale_stock": 2189.69,
#             "expected_price": 2800.0
#         }
#     },
#     "2025-10-18": {
#         "S1002": {
#             "expected_sale_stock": 0.72,
#             "expected_price": 2000.0
#         },
#         "S1004": {
#             "expected_sale_stock": 0.37,
#             "expected_price": 2500.0
#         },
#         "R1002": {
#             "expected_sale_stock": 1.08,
#             "expected_price": 2200.0
#         },
#         "F1003": {
#             "expected_sale_stock": 1.26,
#             "expected_price": 5500.0
#         },
#         "F1001": {
#             "expected_sale_stock": 1.58,
#             "expected_price": 1300.0
#         },
#         "F1002": {
#             "expected_sale_stock": 1.7,
#             "expected_price": 2500.0
#         },
#         "M1204": {
#             "expected_sale_stock": 0.02,
#             "expected_price": 1900.0
#         },
#         "S1005": {
#             "expected_sale_stock": 0.79,
#             "expected_price": 700.0
#         },
#         "S1006": {
#             "expected_sale_stock": -0.27,
#             "expected_price": 3000.0
#         },
#         "R1003": {
#             "expected_sale_stock": 0.76,
#             "expected_price": NaN
#         },
#         "S1001": {
#             "expected_sale_stock": 1.61,
#             "expected_price": 6000.0
#         },
#         "M1001": {
#             "expected_sale_stock": 7.94,
#             "expected_price": 1500.0
#         },
#         "M1101": {
#             "expected_sale_stock": 12.38,
#             "expected_price": 1500.0
#         },
#         "S1003": {
#             "expected_sale_stock": 0.81,
#             "expected_price": 900.0
#         },
#         "R1001": {
#             "expected_sale_stock": 0.35,
#             "expected_price": 1800.0
#         },
#         "M1401": {
#             "expected_sale_stock": 47.33,
#             "expected_price": 10000.0
#         },
#         "M1203": {
#             "expected_sale_stock": 0.17,
#             "expected_price": 2100.0
#         },
#         "M1201": {
#             "expected_sale_stock": 0.09,
#             "expected_price": 2000.0
#         },
#         "M1205": {
#             "expected_sale_stock": 0.72,
#             "expected_price": 2500.0
#         },
#         "M1202": {
#             "expected_sale_stock": -0.05,
#             "expected_price": 2200.0
#         },
#         "M1301": {
#             "expected_sale_stock": 5491.15,
#             "expected_price": 2800.0
#         }
#     },
#     "2025-10-19": {
#         "S1002": {
#             "expected_sale_stock": 1.87,
#             "expected_price": 2000.0
#         },
#         "S1004": {
#             "expected_sale_stock": 0.48,
#             "expected_price": 2500.0
#         },
#         "R1002": {
#             "expected_sale_stock": 0.96,
#             "expected_price": 2200.0
#         },
#         "F1003": {
#             "expected_sale_stock": 1.44,
#             "expected_price": 5500.0
#         },
#         "F1001": {
#             "expected_sale_stock": 1.56,
#             "expected_price": 1300.0
#         },
#         "F1002": {
#             "expected_sale_stock": 1.76,
#             "expected_price": 2500.0
#         },
#         "M1204": {
#             "expected_sale_stock": 0.13,
#             "expected_price": 1900.0
#         },
#         "S1005": {
#             "expected_sale_stock": 0.43,
#             "expected_price": 700.0
#         },
#         "S1006": {
#             "expected_sale_stock": 1.24,
#             "expected_price": 3000.0
#         },
#         "R1003": {
#             "expected_sale_stock": 0.76,
#             "expected_price": NaN
#         },
#         "S1001": {
#             "expected_sale_stock": 1.79,
#             "expected_price": 6000.0
#         },
#         "M1001": {
#             "expected_sale_stock": 8.28,
#             "expected_price": 1500.0
#         },
#         "M1101": {
#             "expected_sale_stock": 13.45,
#             "expected_price": 1500.0
#         },
#         "S1003": {
#             "expected_sale_stock": 0.7,
#             "expected_price": 900.0
#         },
#         "R1001": {
#             "expected_sale_stock": 0.61,
#             "expected_price": 1800.0
#         },
#         "M1401": {
#             "expected_sale_stock": 78.33,
#             "expected_price": 10000.0
#         },
#         "M1203": {
#             "expected_sale_stock": 0.05,
#             "expected_price": 2100.0
#         },
#         "M1201": {
#             "expected_sale_stock": 0.16,
#             "expected_price": 2000.0
#         },
#         "M1205": {
#             "expected_sale_stock": 0.85,
#             "expected_price": 2500.0
#         },
#         "M1202": {
#             "expected_sale_stock": 0.02,
#             "expected_price": 2200.0
#         },
#         "M1301": {
#             "expected_sale_stock": 13761.91,
#             "expected_price": 2800.0
#         }
#     }
# }
